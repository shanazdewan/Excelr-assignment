# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import sklearn
from sklearn.cluster import DBSCAN
from scipy.cluster.hierarchy import linkage
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering

# %%
airlines = pd.read_csv("C:\\Users\\Shanaz Dewan\\OneDrive\\Documents\\DS Assignment\\eastwestairlines.csv")
airlines
# Out:
#        ID#  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.shape
# Out:
# (3999, 12)

# %%
airlines.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3999 entries, 0 to 3998
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   ID#                3999 non-null   int64
#  1   Balance            3999 non-null   int64
#  2   Qual_miles         3999 non-null   int64
#  3   cc1_miles          3999 non-null   int64
#  4   cc2_miles          3999 non-null   int64
#  5   cc3_miles          3999 non-null   int64
#  6   Bonus_miles        3999 non-null   int64
#  7   Bonus_trans        3999 non-null   int64
#  8   Flight_miles_12mo  3999 non-null   int64
#  9   Flight_trans_12    3999 non-null   int64
#  10  Days_since_enroll  3999 non-null   int64
#  11  Award?             3999 non-null   int64
# dtypes: int64(12)
# memory usage: 375.0 KB

# %%
airlines.isnull().sum()
# Out:
# ID#                  0
# Balance              0
# Qual_miles           0
# cc1_miles            0
# cc2_miles            0
# cc3_miles            0
# Bonus_miles          0
# Bonus_trans          0
# Flight_miles_12mo    0
# Flight_trans_12      0
# Days_since_enroll    0
# Award?               0
# dtype: int64

# %%
airlines.columns
# Out:
# Index(['ID#', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award?'],
#       dtype='object')

# %%
airlines = airlines.rename({'ID#':'Id','Award?':'Award'},axis=1)
airlines
# Out:
#         Id  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.columns
# Out:
# Index(['Id', 'Balance', 'Qual_miles', 'cc1_miles', 'cc2_miles', 'cc3_miles',
#        'Bonus_miles', 'Bonus_trans', 'Flight_miles_12mo', 'Flight_trans_12',
#        'Days_since_enroll', 'Award'],
#       dtype='object')

# %%
airlines.describe()
# Out:
#                 Id       Balance    Qual_miles    cc1_miles    cc2_miles  \
# count  3999.000000  3.999000e+03   3999.000000  3999.000000  3999.000000
# mean   2014.819455  7.360133e+04    144.114529     2.059515     1.014504
# std    1160.764358  1.007757e+05    773.663804     1.376919     0.147650
# min       1.000000  0.000000e+00      0.000000     1.000000     1.000000
# 25%    1010.500000  1.852750e+04      0.000000     1.000000     1.000000
# 50%    2016.000000  4.309700e+04      0.000000     1.000000     1.000000
# 75%    3020.500000  9.240400e+04      0.000000     3.000000     1.000000
# max    4021.000000  1.704838e+06  11148.000000     5.000000     3.000000
#
#          cc3_miles    Bonus_miles  Bonus_trans  Flight_miles_12mo  \
# count  3999.000000    3999.000000   3999.00000        3999.000000
# mean      1.012253   17144.846212     11.60190         460.055764
# std       0.195241   24150.967826      9.60381        1400.209171
# ...

# %% [markdown]
# ### Normalization of the data

# %%
def norm_func(i):
    x = (i-i.min())/(i.max()-i.min())
    return x

# %%
df_norm = norm_func(airlines.iloc[:,1:])
df_norm
# Out:
#        Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0     0.016508         0.0       0.00        0.0        0.0     0.000660
# 1     0.011288         0.0       0.00        0.0        0.0     0.000815
# 2     0.024257         0.0       0.00        0.0        0.0     0.015636
# 3     0.008667         0.0       0.00        0.0        0.0     0.001896
# 4     0.057338         0.0       0.75        0.0        0.0     0.164211
# ...        ...         ...        ...        ...        ...          ...
# 3994  0.010837         0.0       0.00        0.0        0.0     0.032330
# 3995  0.037766         0.0       0.00        0.0        0.0     0.003720
# 3996  0.043169         0.0       0.50        0.0        0.0     0.096505
# 3997  0.032202         0.0       0.00        0.0        0.0     0.001896
# 3998  0.001769         0.0       0.00        0.0        0.0     0.000000
#
#       Bonus_trans  Flight_miles_12mo  Flight_trans_12  Days_since_enroll  \
# ...

# %% [markdown]
# ## KMeans Clustering

# %%
scaler = StandardScaler()
scaler_df = scaler.fit_transform(airlines.iloc[:,1:])
scaler_df
# Out:
# array([[-4.51140783e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.39545434e+00, -7.66919299e-01],
#        [-5.39456874e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.37995704e+00, -7.66919299e-01],
#        [-3.20031232e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01,  1.41192021e+00, -7.66919299e-01],
#        ...,
#        [-4.29480975e-05, -1.86298687e-01,  6.83121167e-01, ...,
#         -3.62167870e-01, -1.31560393e+00,  1.30391816e+00],
#        [-1.85606976e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -9.85033311e-02, -1.31608822e+00, -7.66919299e-01],
#        [-7.00507951e-01, -1.86298687e-01, -7.69578406e-01, ...,
#         -3.62167870e-01, -1.31754109e+00, -7.66919299e-01]])

# %%
fig = plt.figure(figsize=(10,8))
WCSS = []
for i in range(1,11):
    km = KMeans(n_clusters= i)
    km.fit(df_norm)
    WCSS.append(km.inertia_)
plt.plot(range(1,11),WCSS)
plt.title("Elbow Method")
plt.ylabel("WCSS")
plt.xlabel("Number of clusters")
plt.show()

# %%
cluster = KMeans(n_clusters=5,random_state=42)
k = cluster.fit_predict(scaler_df)

# %%
k
# Out:
# array([1, 1, 1, ..., 3, 1, 1])

# %%
c_k = pd.Series(k)
c_k
# Out:
# 0       1
# 1       1
# 2       1
# 3       1
# 4       3
#        ..
# 3994    1
# 3995    1
# 3996    3
# 3997    1
# 3998    1
# Length: 3999, dtype: int32

# %%
airlines_Kmeans = airlines.copy()
airlines_Kmeans["K_clust"] = c_k
airlines_Kmeans
# Out:
#         Id  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
sklearn.metrics.silhouette_score(scaler_df,k)
# Out:
# 0.32490482900380546

# %%
airlines.iloc[:,1:].groupby(airlines_Kmeans.K_clust).mean()
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# K_clust
# 0        188455.641176  961.558824   2.194118   1.000000   1.000000
# 1         44293.077409   98.530806   1.237362   1.000000   1.000395
# 2         68876.581395   23.255814   1.139535   2.348837   1.000000
# 3        117119.906376  130.094431   3.736077   1.000000   1.001614
# 4        138061.400000   78.800000   3.466667   1.000000   4.066667
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# K_clust
# 0        30945.770588    26.111765        5277.958824        15.258824
# 1         4722.390205     6.885861         196.838468         0.614929
# 2        14689.837209    17.534884         582.627907         2.209302
# 3        39793.209040    18.843422         332.092010         0.987086
# 4        93927.866667    28.066667         506.666667         1.600000
#
#          Days_since_enroll     Award
# K_clust
# 0              4678.300000  0.800000
# ...

# %% [markdown]
# ## DBSCAN

# %%
dbscan = DBSCAN(eps = 5, min_samples = 13)
dbscan.fit(scaler_df)
# Out:
# DBSCAN(eps=5, min_samples=13)

# %%
dbscan.labels_
# Out:
# array([0, 0, 0, ..., 0, 0, 0], dtype=int64)

# %%
c_d = pd.Series(dbscan.labels_)
c_d
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 3994    0
# 3995    0
# 3996    0
# 3997    0
# 3998    0
# Length: 3999, dtype: int64

# %%
airlines_dbscan = airlines.copy()

# %%
airlines_dbscan['D_clust'] = c_d
airlines_dbscan
# Out:
#         Id  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
sklearn.metrics.silhouette_score(scaler_df,c_d)
# Out:
# 0.5474248634702347

# %%
airlines.iloc[:,1:].groupby(airlines_dbscan.D_clust).mean()
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# D_clust
# -1       267161.185185  566.629630   2.962963        1.0   2.814815
#  0        72322.897429  142.533724   2.063375        1.0   1.000000
#  1        52231.400000   66.666667   1.000000        3.0   1.000000
#  2        77793.642857    0.000000   1.214286        2.0   1.000000
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# D_clust
# -1       79186.074074    33.518519        4339.037037        11.444444
#  0       16745.368542    11.386358         432.058030         1.295241
#  1       20410.466667    18.933333         692.666667         3.200000
#  2       11625.214286    16.785714         523.678571         1.678571
#
#          Days_since_enroll     Award
# D_clust
# -1             4529.481481  0.666667
#  0             4117.373123  0.368033
#  1             4075.533333  0.400000
#  2             3911.821429  0.392857

# %% [markdown]
# ## Hierarchical Clustering

# %%
z = linkage(df_norm,method='average',metric='euclidean')
plt.figure(figsize=(15,10))
plt.title("Hierarchical Clustering Dendrogram")
plt.xlabel("Index")
plt.ylabel("Distance")
sch.dendrogram(z)
plt.show()

# %%
hc = AgglomerativeClustering(n_clusters=5,linkage="complete",affinity="euclidean").fit(df_norm)

# %%
hc.labels_
# Out:
# array([0, 0, 0, ..., 2, 0, 0], dtype=int64)

# %%
cluster_hc = pd.Series(hc.labels_)
cluster_hc
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 3994    2
# 3995    2
# 3996    2
# 3997    0
# 3998    0
# Length: 3999, dtype: int64

# %%
sklearn.metrics.silhouette_score(scaler_df,cluster_hc)
# Out:
# 0.24966907173038302

# %%
airlines_HC = airlines.copy()
airlines_HC['H_clust'] = cluster_hc
airlines_HC
# Out:
#         Id  Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  Bonus_miles  \
# 0        1    28143           0          1          1          1          174
# 1        2    19244           0          1          1          1          215
# 2        3    41354           0          1          1          1         4123
# 3        4    14776           0          1          1          1          500
# 4        5    97752           0          4          1          1        43300
# ...    ...      ...         ...        ...        ...        ...          ...
# 3994  4017    18476           0          1          1          1         8525
# 3995  4018    64385           0          1          1          1          981
# 3996  4019    73597           0          3          1          1        25447
# 3997  4020    54899           0          1          1          1          500
# 3998  4021     3016           0          1          1          1            0
#
# ...

# %%
airlines.iloc[:,1:].groupby(airlines_HC.H_clust).mean()
# Out:
#                Balance  Qual_miles  cc1_miles  cc2_miles  cc3_miles  \
# H_clust
# 0         59968.433667   88.883768   1.712224   1.000401   1.011222
# 1        157084.578462  208.673846   4.661538   1.000000   1.061538
# 2         80173.963287  248.550699   2.104895   1.009615   1.000874
# 3        131999.500000  347.000000   2.500000   1.000000   1.000000
# 4         45515.064516   32.258065   1.000000   2.483871   1.000000
#
#           Bonus_miles  Bonus_trans  Flight_miles_12mo  Flight_trans_12  \
# H_clust
# 0        10271.530261     9.105812         227.797194         0.656112
# 1        70477.086154    23.249231        1019.433846         3.196923
# 2        16882.864510    13.412587         739.958916         2.236888
# 3        65634.250000    69.250000       19960.000000        49.250000
# 4        14618.870968    16.129032         443.225806         1.967742
#
#          Days_since_enroll     Award
# H_clust
# 0              3825.392786  0.000802
# ...
